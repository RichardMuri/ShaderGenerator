# %% [markdown]
# <a href="https://colab.research.google.com/github/RichardMuri/ShaderGenerator/blob/main/6_864_CodeBertASN_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pulls repo and download the data
# %%bash
!(stat -t /usr/local/lib/*/dist-packages/google/colab > /dev/null 2>&1) && exit
rm -rf ShaderGenerator
git clone \
    --depth 1 \
    --filter=blob:none \
    --no-checkout \
    https://github.com/RichardMuri/ShaderGenerator.git
cd ShaderGenerator
git checkout main -- torchASN/ card2code/third_party/hearthstone
# Out:
# Cloning into 'ShaderGenerator'...

# %%
# !pip install torch
# !pip install transformers
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.10.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.10.0.2)
# Collecting transformers
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 5.2 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 46.8 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 49.2 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.2.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 542 kB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 43.3 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.2.1 pyyaml-6.0 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.12.5

# %%
import sys
sys.path.append("/content/ShaderGenerator/")
sys.path.append("/content/ShaderGenerator/torchASN/")
import numpy as np
import random
import torch
from torch import cuda
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from tqdm import tqdm
from dataclasses import dataclass

from common.config import *
from components.dataset import *

from grammar.grammar import Grammar

from grammar.python3.python3_transition_system import Python3TransitionSystem
# from models.ASN import ASNParser
from models.CodeBertASN import ASNParser
from models import nn_utils

from torch import optim
import os
import time

seed = 0
random.seed(seed)
np.random.seed(seed)

device = None
if cuda.is_available():
  device = 'cuda'
  torch.cuda.manual_seed_all(seed)
else:
  print('WARNING: you are running this project on a cpu!')
  device = 'cpu'

# %%
# %%bash
# cd ShaderGenerator/
# export PYTHONPATH="${PYTHONPATH}:torchASN/"
# python torchASN/datasets/hearthstone/make_dataset.py
# Out:
# number of word types: 1268, number of word types w/ frequency > 1: 485
# singletons: ['Acidic', 'Swamp', 'Animal', 'Companion', 'Companion.', 'Explosion', 'Intellect', 'Missiles', 'Arcanite', 'Assassinate', 'Backstab', '+4/+4.', '<i>(+4', 'Attack/+4', 'Health)</i>', 'Bloodfen', 'Raptor', 'Bloodlust', 'Bluegill', 'Charge', 'Chillwind', 'Cleave', 'Consecration', 'Corruption', 'Dalaran', 'Mechanic', 'Dragonling.', 'Drain', 'Infernal', 'Elven', 'Archer', 'Excess', '<i>(You', 'tray.)</i>', 'Execute', 'Fan', 'Knives', 'Fireball', 'Flamestrike', 'Flametongue', 'Frostbolt', 'Frostwolf', 'Grunt', 'Goldshire', 'Footman', 'Grimscale', 'Gurubashi', 'Hammer', 'Protection', 'Touch', 'Hex', '0/1', '#6', 'Smite', 'Houndmaster', 'Huffer', 'Humility', "Hunter's", 'Ironforge', 'Rifleman', 'Ironfur', 'Grizzly', 'Kill', 'Command', 'Kobold', 'Geomancer', "Kor'kron", 'Elite', 'Leokk', "Light's", 'Arena', 'Vision', '0/2', 'Misha', 'Moonfire', 'Scout', 'Tidehunter', 'Scout.', 'Nightblade', '<b>Battlecry:', '</b>Deal', 'Northshire', 'Novice', 'Engineer', 'Oasis', 'Snapjaw', 'Magi', 'Raid', 'Leader', 'Razorfen', 'Boar.', 'Reckless', 'Rocketeer', 'River', 'Crocolisk', 'Rockbiter', 'Sacrificial', 'Pact', 'Sap', 'Savage', 'Roar', 'Shattered', 'Sun', 'Shiv', 'Recruit', 'Soulfire', 'Discard', 'Sprint', 'Starfire', 'Starving', 'Buzzard', 'Stonetusk', 'Stormpike', 'Commando', 'Stormwind', 'Swipe', 'Timber', 'Totemic', 'Totems', 'Tracking', 'Look', 'others.', 'Truesilver', 'Tundra', 'Rhino', 'Vanish', 'Voidwalker', 'Warsong', 'Attack,', 'Water', 'Whirlwind', 'Wicked', 'Knife', 'Growth', 'empty', 'Crystal.', 'Windspeaker', 'Wolfrider', "Alexstrasza's", 'Knowledge', '<b>Overload:', '(2)</b>', "Anub'arak", 'gets', 'bonus', 'Damage</b>.', 'Horserider', 'Watchman', 'Can', 'normal', 'Armored', 'Warhorse', 'Searing', 'Tournament', 'Medic', 'Air', "Ancestor's", 'Anima', 'one.', 'Antique', 'Healbot', 'Nullifier', 'X-21', 'Plating', 'Blingtron', '3000', 'player.', 'Bolvar', 'Fordragon', 'dies', 'hand,', 'Bomb', 'Lobber', '<b>Deathrattle</b>:', 'Bouncing', 'Repeat', 'Pet', 'Cobalt', 'Coghammer', 'Cogmaster', 'Mech.', 'Crush', 'Wispers', 'Wisps;', 'Darkbomb', 'Demonheart', 'Dr.', 'Bots.', '<i>WARNING:', 'Bots', 'may', 'explode.</i>', 'transform', '7/7.', 'Dunemaul', 'Overload:', '(1)</b>', 'Enhance-o', 'Mechano', '<b>Windfury</b>,', '<b>Taunt</b>,', '<i>(at', 'random)</i>', 'Feign', 'Trigger', 'non-Mech', 'Reaver', 'remove', 'Finicky', 'Cloakfield', 'Leviathan', 'this,', 'Flamecannon', 'Foe', '4000', 'Also', 'damages', 'whomever', 'he', 'attacks.', 'Force-Tank', 'MAX', "Gahz'rilla", "Gallywix's", 'Coin', 'Crystal', 'only.', "<i>(Won't", 'Gallywix.)</i>', 'Gazlowe', '1-mana', 'Gilblin', 'Stalker', 'Glaivezooka', 'Gnomeregan', 'Infantry', 'Blastmage', 'Sapper', 'Tender', 'Crystal;', 'Hemet', 'Nesingwary', 'Beast.', 'Hobgoblin', '1-Attack', 'Illuminator', 'health', 'Imp-losion', '$2-$4', 'dealt.', 'Jeeves', 'they', 'Junkbot', 'Kezan', 'Mystic', '<b>Secret</b>.', 'Naaru', '#3', 'still', 'damaged,', 'Lightwarden.', 'Lightbomb', "Lil'", 'Exorcist', '<b>Deathrattle</b>', 'Lost', 'Tallstrider', 'Malorne', 'Mech-Bear-Cat', 'Part.</b>', 'Mechwarper', 'Mekgineer', 'Thermaplugg', 'Gnome.', 'Metaltooth', 'Leaper', 'Micro', 'Machine', "Mimiron's", 'Head', 'Mechs,', 'form', 'V-07-TR-0N.', 'Mogor', 'Muster', 'Recruits.', '1/4', 'Weapon.', 'Neptulon', 'Brute', 'Ninja', 'Warmaul', 'One-eyed', 'Cheat', 'Piloted', 'Shredder', '2-Cost', 'Puddlestomper', 'Quartermaster', 'Recruits', 'Recombobulator', 'same', 'Cost.', 'Recycle', 'Reversing', 'Switch', 'Rusty', 'Horn', 'Sabotage', '<b>Combo</b>:', 'And', 'Salty', 'Dog', 'Seal', 'Shadowbomber', 'Shadowboxer', 'Shielded', 'Minibot', 'Shieldmaiden', "Ship's", 'Shrinkmeister', '-2', 'Siege', 'Engine', 'Armor,', 'Snowchugger', 'Soot', 'Spewer', 'Tank', 'Steamwheedle', 'Sniper', 'Stonesplinter', 'Trogg', 'Target', 'Dummy', 'Time', 'Rewinder', "Tinker's", 'Sharpsword', 'Oil', 'Trade', 'Prince', 'Gallywix', 'Coin.', 'Tree', 'Troggzor', 'Earthinator', 'Burly', 'Rockjaw', 'Trogg.', 'Portal', 'Upgraded', 'Repair', 'V-07-TR-0N',  ...
# word types not included: ['Acidic', 'Swamp', 'Animal', 'Companion', 'Companion.', 'Explosion', 'Intellect', 'Missiles', 'Arcanite', 'Assassinate', 'Backstab', '+4/+4.', '<i>(+4', 'Attack/+4', 'Health)</i>', 'Bloodfen', 'Raptor', 'Bloodlust', 'Bluegill', 'Charge', 'Chillwind', 'Cleave', 'Consecration', 'Corruption', 'Dalaran', 'Mechanic', 'Dragonling.', 'Drain', 'Infernal', 'Elven', 'Archer', 'Excess', '<i>(You', 'tray.)</i>', 'Execute', 'Fan', 'Knives', 'Fireball', 'Flamestrike', 'Flametongue', 'Frostbolt', 'Frostwolf', 'Grunt', 'Goldshire', 'Footman', 'Grimscale', 'Gurubashi', 'Hammer', 'Protection', 'Touch', 'Hex', '0/1', '#6', 'Smite', 'Houndmaster', 'Huffer', 'Humility', "Hunter's", 'Ironforge', 'Rifleman', 'Ironfur', 'Grizzly', 'Kill', 'Command', 'Kobold', 'Geomancer', "Kor'kron", 'Elite', 'Leokk', "Light's", 'Arena', 'Vision', '0/2', 'Misha', 'Moonfire', 'Scout', 'Tidehunter', 'Scout.', 'Nightblade', '<b>Battlecry:', '</b>Deal', 'Northshire', 'Novice', 'Engineer', 'Oasis', 'Snapjaw', 'Magi', 'Raid', 'Leader', 'Razorfen', 'Boar.', 'Reckless', 'Rocketeer', 'River', 'Crocolisk', 'Rockbiter', 'Sacrificial', 'Pact', 'Sap', 'Savage', 'Roar', 'Shattered', 'Sun', 'Shiv', 'Recruit', 'Soulfire', 'Discard', 'Sprint', 'Starfire', 'Starving', 'Buzzard', 'Stonetusk', 'Stormpike', 'Commando', 'Stormwind', 'Swipe', 'Timber', 'Totemic', 'Totems', 'Tracking', 'Look', 'others.', 'Truesilver', 'Tundra', 'Rhino', 'Vanish', 'Voidwalker', 'Warsong', 'Attack,', 'Water', 'Whirlwind', 'Wicked', 'Knife', 'Growth', 'empty', 'Crystal.', 'Windspeaker', 'Wolfrider', "Alexstrasza's", 'Knowledge', '<b>Overload:', '(2)</b>', "Anub'arak", 'gets', 'bonus', 'Damage</b>.', 'Horserider', 'Watchman', 'Can', 'normal', 'Armored', 'Warhorse', 'Searing', 'Tournament', 'Medic', 'Air', "Ancestor's", 'Anima', 'one.', 'Antique', 'Healbot', 'Nullifier', 'X-21', 'Plating', 'Blingtron', '3000', 'player.', 'Bolvar', 'Fordragon', 'dies', 'hand,', 'Bomb', 'Lobber', '<b>Deathrattle</b>:', 'Bouncing', 'Repeat', 'Pet', 'Cobalt', 'Coghammer', 'Cogmaster', 'Mech.', 'Crush', 'Wispers', 'Wisps;', 'Darkbomb', 'Demonheart', 'Dr.', 'Bots.', '<i>WARNING:', 'Bots', 'may', 'explode.</i>', 'transform', '7/7.', 'Dunemaul', 'Overload:', '(1)</b>', 'Enhance-o', 'Mechano', '<b>Windfury</b>,', '<b>Taunt</b>,', '<i>(at', 'random)</i>', 'Feign', 'Trigger', 'non-Mech', 'Reaver', 'remove', 'Finicky', 'Cloakfield', 'Leviathan', 'this,', 'Flamecannon', 'Foe', '4000', 'Also', 'damages', 'whomever', 'he', 'attacks.', 'Force-Tank', 'MAX', "Gahz'rilla", "Gallywix's", 'Coin', 'Crystal', 'only.', "<i>(Won't", 'Gallywix.)</i>', 'Gazlowe', '1-mana', 'Gilblin', 'Stalker', 'Glaivezooka', 'Gnomeregan', 'Infantry', 'Blastmage', 'Sapper', 'Tender', 'Crystal;', 'Hemet', 'Nesingwary', 'Beast.', 'Hobgoblin', '1-Attack', 'Illuminator', 'health', 'Imp-losion', '$2-$4', 'dealt.', 'Jeeves', 'they', 'Junkbot', 'Kezan', 'Mystic', '<b>Secret</b>.', 'Naaru', '#3', 'still', 'damaged,', 'Lightwarden.', 'Lightbomb', "Lil'", 'Exorcist', '<b>Deathrattle</b>', 'Lost', 'Tallstrider', 'Malorne', 'Mech-Bear-Cat', 'Part.</b>', 'Mechwarper', 'Mekgineer', 'Thermaplugg', 'Gnome.', 'Metaltooth', 'Leaper', 'Micro', 'Machine', "Mimiron's", 'Head', 'Mechs,', 'form', 'V-07-TR-0N.', 'Mogor', 'Muster', 'Recruits.', '1/4', 'Weapon.', 'Neptulon', 'Brute', 'Ninja', 'Warmaul', 'One-eyed', 'Cheat', 'Piloted', 'Shredder', '2-Cost', 'Puddlestomper', 'Quartermaster', 'Recruits', 'Recombobulator', 'same', 'Cost.', 'Recycle', 'Reversing', 'Switch', 'Rusty', 'Horn', 'Sabotage', '<b>Combo</b>:', 'And', 'Salty', 'Dog', 'Seal', 'Shadowbomber', 'Shadowboxer', 'Shielded', 'Minibot', 'Shieldmaiden', "Ship's", 'Shrinkmeister', '-2', 'Siege', 'Engine', 'Armor,', 'Snowchugger', 'Soot', 'Spewer', 'Tank', 'Steamwheedle', 'Sniper', 'Stonesplinter', 'Trogg', 'Target', 'Dummy', 'Time', 'Rewinder', "Tinker's", 'Sharpsword', 'Oil', 'Trade', 'Prince', 'Gallywix', 'Coin.', 'Tree', 'Troggzor', 'Earthinator', 'Burly', 'Rockjaw', 'Trogg.', 'Portal', 'Upgraded', 'Repair', ' ...
# number of word types: 2471, number of word types w/ frequency > 1: 622
# singletons: ['AcidicSwampOoze(MinionCard):', 'super().__init__("Acidic', 'Swamp', 'battlecry=Battlecry(Destroy(),', 'AncestralHealing(SpellCard):', 'self.target.heal(player.effective_heal_power(self.target.calculate_max_health()),', 'self.target.taunt', 'AnimalCompanion(SpellCard):', 'super().__init__("Animal', 'Companion",', 'beast_list', '[hearthbreaker.cards.minions.hunter.Huffer(),', 'hearthbreaker.cards.minions.hunter.Misha(),', 'hearthbreaker.cards.minions.hunter.Leokk()]', 'game.random_choice(beast_list)', 'ArcaneExplosion(SpellCard):', 'Explosion",', 'ArcaneIntellect(SpellCard):', 'Intellect",', 'ArcaneMissiles(SpellCard):', 'Missiles",', 'player.effective_spell_damage(3)):', 'ArcaneShot(SpellCard):', 'ArcaniteReaper(WeaponCard):', 'super().__init__("Arcanite', 'Reaper",', 'Assassinate(SpellCard):', 'super().__init__("Assassinate",', 'Backstab(SpellCard):', 'super().__init__("Backstab",', 'BlessingOfKings(SpellCard):', 'BlessingOfMight(SpellCard):', 'BloodfenRaptor(MinionCard):', 'super().__init__("Bloodfen', 'Raptor",', 'Bloodlust(SpellCard):', 'super().__init__("Bloodlust",', 'minion.change_temp_attack(3)', 'BluegillWarrior(MinionCard):', 'super().__init__("Bluegill', 'Boar(MinionCard):', 'super().__init__("Boar",', 'Charge(SpellCard):', 'super().__init__("Charge",', 'self.target.add_buff(Buff(_Charge()))', 'ChillwindYeti(MinionCard):', 'super().__init__("Chillwind', 'Claw(SpellCard):', 'super().__init__("Claw",', 'player.hero.increase_armor(2)', 'Cleave(SpellCard):', 'super().__init__("Cleave",', 'Consecration(SpellCard):', 'super().__init__("Consecration",', 'CoreHound(MinionCard):', 'Hound",', 'Corruption(SpellCard):', 'super().__init__("Corruption",', 'self.target.add_effect(Effect(TurnStarted(player=EnemyPlayer()),', 'DalaranMage(MinionCard):', 'super().__init__("Dalaran', 'DivineSpirit(SpellCard):', 'self.target.increase_health(self.target.health)', 'DragonlingMechanic(MinionCard):', 'super().__init__("Dragonling', 'Mechanic",', 'battlecry=Battlecry(Summon(MechanicalDragonling()),', 'DrainLife(SpellCard):', 'super().__init__("Drain', 'player.hero.heal(player.effective_heal_power(2),', 'DreadInfernal(MinionCard):', 'Infernal",', 'CharacterSelector(players=BothPlayer())))', 'ElvenArcher(MinionCard):', 'super().__init__("Elven', 'Archer",', 'ExcessMana(SpellCard):', 'super().__init__("Excess', 'Mana",', 'Execute(SpellCard):', 'super().__init__("Execute",', 'target_func=hearthbreaker.targeting.find_enemy_minion_spell_target,', 'FanOfKnives(SpellCard):', 'super().__init__("Fan', 'Knives",', 'Fireball(SpellCard):', 'super().__init__("Fireball",', 'Flamestrike(SpellCard):', 'super().__init__("Flamestrike",', 'minion.damage(player.effective_spell_damage(4),', 'FlametongueTotem(MinionCard):', 'super().__init__("Flametongue', 'Frog(MinionCard):', 'super().__init__("Frog",', 'FrostNova(SpellCard):', 'FrostShock(SpellCard):', 'Frostbolt(SpellCard):', 'super().__init__("Frostbolt",', 'FrostwolfGrunt(MinionCard):', 'super().__init__("Frostwolf', 'Grunt",', 'GoldshireFootman(MinionCard):', 'super().__init__("Goldshire', 'Footman",', 'GrimscaleOracle(MinionCard):', 'super().__init__("Grimscale', 'GuardianOfKings(MinionCard):', 'super().__init__("Guardian', 'battlecry=Battlecry(Heal(6),', 'GurubashiBerserker(MinionCard):', 'super().__init__("Gurubashi', 'effects=[Effect(CharacterDamaged(condition=MinionIsTarget()),', 'ActionTag(Give(ChangeAttack(3)),', 'HammerOfWrath(SpellCard):', 'super().__init__("Hammer', 'HandOfProtection(SpellCard):', 'super().__init__("Hand', 'Protection",', 'HealingTouch(SpellCard):', 'Touch",', 'Hex(SpellCard):', 'super().__init__("Hex",', 'hearthbreaker.cards.minions.neutral.Frog()', 'frog.create_minion(None)', 'minion.card', 'self.target.replace(minion)', 'HolyLight(SpellCard):', 'self.target.heal(player.effective_heal_power(6),', 'HolyNova(SpellCard):', 'minion.heal(player.effective_heal_power(2),', 'HolySmite(SpellCard):', 'Smite",', 'Houndmaster(MinionCard):', 'super().__init__("Houndmaster",', 'ba ...
# word types not included: []
# number of word types: 0, number of word types w/ frequency > 1: 0
# singletons: []
# word types not included: []
# number of word types: 0, number of word types w/ frequency > 1: 0
# singletons: []
# word types not included: []
# number of word types: 945, number of word types w/ frequency > 1: 396
# singletons: ['AcidicSwampOoze', 'AncestralHealing', 'AnimalCompanion', 'ArcaneExplosion', 'ArcaneIntellect', 'ArcaneMissiles', 'ArcaneShot', 'ArcaniteReaper', 'Assassinate', 'Backstab', 'BlessingOfKings', 'BlessingOfMight', 'BloodfenRaptor', 'Bloodlust', '_Charge', 'ChillwindYeti', 'Claw', 'Cleave', 'Consecration', 'CoreHound', 'Corruption', 'DalaranMage', 'DivineSpirit', 'DragonlingMechanic', 'DrainLife', 'DreadInfernal', 'ElvenArcher', 'Execute', 'FanOfKnives', 'Fireball', 'Flamestrike', 'FlametongueTotem', 'FrostNova', 'FrostShock', 'Frostbolt', 'FrostwolfGrunt', 'GoldshireFootman', 'GuardianOfKings', 'GurubashiBerserker', 'MinionIsTarget', 'HammerOfWrath', 'HandOfProtection', 'HealingTouch', 'Hex', 'neutral', 'replace', 'HolyLight', 'HolyNova', 'HolySmite', 'Houndmaster', 'Humility', 'HuntersMark', 'IronforgeRifleman', 'IronfurGrizzly', 'KillCommand', 'KoboldGeomancer', 'KorkronElite', 'LordOfTheArena', 'MindBlast', 'MindControl', 'MindVision', 'deepcopy', 'Nightblade', 'NorthshireCleric', 'NoviceEngineer', 'OasisSnapjaw', 'OgreMagi', 'RaidLeader', 'RazorfenHunter', 'RecklessRocketeer', 'RiverCrocolisk', 'RockbiterWeapon', 'find_friendly_spell_target', 'SacrificialPact', 'Sap', 'SavageRoar', 'ShadowBolt', 'ShadowWordDeath', 'ShadowWordPain', 'ShatteredSunCleric', 'Sheep', 'ShieldBlock', 'Shiv', 'Soulfire', 'discard', 'Sprint', 'Starfire', 'StarvingBuzzard', 'StonetuskBoar', 'StormpikeCommando', 'StormwindChampion', 'Swipe', 'TimberWolf', 'TotemicMight', 'Tracking', 'card_index', 'can_draw', 'TruesilverChampion', 'TundraRhino', 'Vanish', 'Voidwalker', 'WarsongCommander', 'WaterElemental', 'Whirlwind', 'WickedKnife', 'WildGrowth', '_Windfury', 'Windspeaker', 'Wolfrider', 'AlexstraszasChampion', 'AncestralKnowledge', 'Anubarak', 'ArcaneBlast', 'ArgentHorserider', 'ArgentLance', 'ArgentWatchman', 'CanAttack', 'ArmoredWarhorse', 'SearingTotem', 'TournamentMedic', 'WrathOfAirTotem', 'AncestorsCall', 'unattach', 'AnimaGolem', 'MinionCountIs', 'AntiqueHealbot', 'ArcaneNullifierX21', 'ArmorPlating', 'Blingtron3000', 'IsWeapon', 'BolvarFordragon', 'BombLobber', 'BouncingBlade', 'bounces', 'CallPet', 'Chicken', 'ClockworkGiant', 'ClockworkGnome', 'CobaltGuardian', 'CobraShot', 'Coghammer', 'Cogmaster', 'Crush', 'DarkWispers', 'choose_target', 'Darkbomb', 'Demonheart', 'DoctorBoom', 'DunemaulShaman', 'EnhanceoMechano', 'ExplosiveSheep', 'FeignDeath', 'double_deathrattle', 'FelCannon', 'FelReaver', 'FinickyCloakfield', 'FlameLeviathan', 'Drawn', 'Flamecannon', 'FoeReaper4000', 'TargetAdjacent', 'ForceTankMAX', 'Gahzrilla', 'DoubleAttack', 'Gazlowe', 'GilblinStalker', 'Glaivezooka', 'GnomereganInfantry', 'GoblinBlastmage', 'GoblinSapper', 'GroveTender', 'GiftOfMana', 'GiveManaCrystal', 'GiftOfCards', 'HemetNesingwary', 'Hobgoblin', 'BaseAttackEqualTo', 'Illuminator', 'Implosion', 'Jeeves', 'Difference', 'Junkbot', 'KezanMystic', 'ENEMY_SECRETS', 'KingOfBeasts', 'LightOfTheNaaru', 'Lightwarden', 'Lightbomb', 'LilExorcist', 'LostTallstrider', 'Malorne', 'MINION', 'add_to_deck', 'MechBearCat', 'MechanicalYeti', 'Mechwarper', 'MekgineerThermaplugg', 'MetaltoothLeaper', 'MicroMachine', 'MimironsHead', 'MogorTheOgre', 'MusterForBattle', 'equip', 'Neptulon', 'SiltfinSpiritwalker', 'OgreBrute', 'OgreNinja', 'OgreWarmaul', 'OneeyedCheat', 'PilotedShredder', 'Quartermaster', 'Recombobulator', 'Recycle', 'ReversingSwitch', 'set_attack_to', 'RustyHorn', 'Sabotage', 'destroy', 'SaltyDog', 'SealOfLight', 'Shadowbomber', 'Shadowboxer', 'ShieldedMinibot', 'Shieldmaiden', 'ShipsCannon', 'Shrinkmeister', 'SiegeEngine', 'ArmorIncreased', 'Snowchugger', 'SootSpewer', 'SpiderTank', 'SteamwheedleSniper', 'PowerTargetsMinions', 'StonesplinterTrogg', 'TargetDummy', 'TimeRewinder', 'TinkersSharpswordOil', 'base_attack', 'TradePrinceGallywix', 'FriendlyPlayer', 'TreeOfLife', 'TroggzorTheEarthinator', 'BurlyRockjawTrogg', 'UnstablePortal', 'UpgradedRepairBot', 'MegaWindfury', 'VelensChosen', 'VitalityTotem', 'WeeSpellstopper', 'NoSpellTarget', 'WhirlingBlades', ' ...
# word types not included: []
# number of word types: 1, number of word types w/ frequency > 1: 1
# singletons: []
# word types not included: []
# number of word types: 18, number of word types w/ frequency > 1: 14
# singletons: ['80', '10000', '100', '20']
# word types not included: []
# number of word types: 3, number of word types w/ frequency > 1: 3
# singletons: []
# word types not included: []
# number of word types: 534, number of word types w/ frequency > 1: 27
# singletons: ['Acidic Swamp Ooze', 'Ancestral Healing', 'Animal Companion', 'Arcane Explosion', 'Arcane Intellect', 'Arcane Missiles', 'Arcane Shot', 'Arcanite Reaper', 'Assassinate', 'Backstab', 'Blessing of Kings', 'Blessing of Might', 'Bloodfen Raptor', 'Bloodlust', 'Bluegill Warrior', 'Boar', 'Charge', 'Chillwind Yeti', 'Claw', 'Cleave', 'Consecration', 'Core Hound', 'Corruption', 'Dalaran Mage', 'Divine Spirit', 'Dragonling Mechanic', 'Drain Life', 'Dread Infernal', 'Elven Archer', 'Excess Mana', 'Execute', 'Fan of Knives', 'Fireball', 'Flamestrike', 'Flametongue Totem', 'Frog', 'Frost Nova', 'Frost Shock', 'Frostbolt', 'Frostwolf Grunt', 'Goldshire Footman', 'Grimscale Oracle', 'Guardian of Kings', 'Gurubashi Berserker', 'Hammer of Wrath', 'Hand of Protection', 'Healing Touch', 'Hex', 'Holy Light', 'Holy Nova', 'Holy Smite', 'Houndmaster', 'Huffer', 'Humility', "Hunter's Mark", 'Ironforge Rifleman', 'Ironfur Grizzly', 'Kill Command', 'Kobold Geomancer', "Kor'kron Elite", 'Leokk', "Light's Justice", 'Lord of the Arena', 'Mechanical Dragonling', 'Mind Blast', 'Mind Control', 'Mind Vision', 'Misha', 'Moonfire', 'Murloc Raider', 'Murloc Scout', 'Murloc Tidehunter', 'Nightblade', 'Northshire Cleric', 'Novice Engineer', 'Oasis Snapjaw', 'Ogre Magi', 'Raid Leader', 'Razorfen Hunter', 'Reckless Rocketeer', 'River Crocolisk', 'Rockbiter Weapon', 'Sacrificial Pact', 'Sap', 'Savage Roar', 'Shadow Bolt', 'Shadow Word: Death', 'Shadow Word: Pain', 'Shattered Sun Cleric', 'Sheep', 'Shield Block', 'Shiv', 'Soulfire', 'Sprint', 'Starfire', 'Starving Buzzard', 'Stonetusk Boar', 'Stormpike Commando', 'Stormwind Champion', 'Swipe', 'Timber Wolf', 'Totemic Might', 'Tracking', 'Truesilver Champion', 'Tundra Rhino', 'Vanish', 'Voidwalker', 'Warsong Commander', 'Water Elemental', 'Whirlwind', 'Wicked Knife', 'Wild Growth', 'Windfury', 'Windspeaker', 'Wolfrider', "Alexstrasza's Champion", 'Ancestral Knowledge', "Anub'arak", 'Arcane Blast', 'Argent Horserider', 'Argent Lance', 'Argent Watchman', 'Armored Warhorse', 'Searing Totem', 'Tournament Medic', 'Wrath of Air Totem', "Ancestor's Call", 'Anima Golem', 'Antique Healbot', 'Arcane Nullifier X-21', 'Armor Plating', 'Blingtron 3000', 'Bolvar Fordragon', 'Bomb Lobber', 'Boom Bot', 'Bouncing Blade', 'Call Pet', 'Chicken', 'Clockwork Giant', 'Clockwork Gnome', 'Cobalt Guardian', 'Cobra Shot', 'Coghammer', 'Cogmaster', 'Crush', 'Dark Wispers', 'Give a minion +5/+5 and Taunt', 'Summon 5 Wisps', 'Darkbomb', 'Demonheart', 'Dr. Boom', 'Dunemaul Shaman', 'Enhance-o Mechano', 'Explosive Sheep', 'Feign Death', 'Fel Cannon', 'Fel Reaver', 'Finicky Cloakfield', 'Flame Leviathan', 'Flamecannon', 'Foe Reaper 4000', 'Force-Tank MAX', "Gahz'rilla", 'Gazlowe', 'Gilblin Stalker', 'Glaivezooka', 'Gnomeregan Infantry', 'Goblin Blastmage', 'Goblin Sapper', 'Grove Tender', 'Hemet Nesingwary', 'Hobgoblin', 'Illuminator', 'Imp-losion', 'Jeeves', 'Junkbot', 'Kezan Mystic', 'King of Beasts', 'Light of the Naaru', 'Lightbomb', "Lil' Exorcist", 'Lost Tallstrider', 'Malorne', 'Mech-Bear-Cat', 'Mechanical Yeti', 'Mechwarper', 'Mekgineer Thermaplugg', 'Metaltooth Leaper', 'Micro Machine', "Mimiron's Head", 'Mogor the Ogre', 'Muster for Battle', 'Neptulon', 'Ogre Brute', 'Ogre Ninja', 'Ogre Warmaul', 'One-eyed Cheat', 'Piloted Shredder', 'Puddlestomper', 'Quartermaster', 'Recombobulator', 'mana', 'Recycle', 'Reversing Switch', 'Rusty Horn', 'Sabotage', 'Salty Dog', 'Seal of Light', 'Shadowbomber', 'Shadowboxer', 'Shielded Minibot', 'Shieldmaiden', "Ship's Cannon", 'Shrinkmeister', 'Siege Engine', 'Snowchugger', 'Soot Spewer', 'Spider Tank', 'Steamwheedle Sniper', 'Stonesplinter Trogg', 'Target Dummy', 'Time Rewinder', "Tinker's Sharpsword Oil", 'Trade Prince Gallywix', 'Tree of Life', 'Troggzor the Earthinator', 'Unstable Portal', 'Upgraded Repair Bot', 'V-07-TR-0N', "Velen's Chosen", 'Vitality Totem', 'Wee Spellstopper', 'Whirling Blades', 'Whirling Zap-o-matic', "Anub'ar Ambusher", 'Avenge', 'Baron Rivendare', 'Dancing Swords' ...
# word types not included: []
# DSLPrimitiveType(bytes) dict_keys(['<unk>'])
# DSLPrimitiveType(constant) dict_keys(['<unk>'])
# DSLPrimitiveType(identifier) dict_keys(['<unk>', 'self', 'player', '__init__', 'super', 'CARD_RARITY', 'CHARACTER_CLASS', 'game', 'Minion', 'MinionCard', 'create_minion', 'use', 'COMMON', 'ALL', 'target', 'MINION_TYPE', 'SpellCard', 'minion_type', 'minions', 'hearthbreaker', 'RARE', 'Battlecry', 'targeting', 'ActionTag', 'Effect', 'battlecry', 'minion', 'PlayerSelector', 'target_func', 'Buff', 'effects', 'MinionSelector', 'SelfSelector', 'damage', 'Give', 'effective_spell_damage', 'targets', 'len', 'LEGENDARY', 'BothPlayer', 'ChangeAttack', 'copy', 'other_player', 'BEAST', 'EPIC', 'FREE', 'find_minion_spell_target', 'MECH', 'players', 'EnemyPlayer', 'DRUID', 'hero', 'picker', 'card', 'can_use', 'deathrattle', 'IsType', 'SHAMAN', 'HUNTER', 'TurnEnded', 'Deathrattle', 'Damage', 'Summon', 'ChangeHealth', 'taunt', 'MAGE', 'PALADIN', 'ROGUE', 'WARLOCK', 'PRIEST', 'UserPicker', '_reveal', 'WARRIOR', 'Aura', 'find_spell_target', 'CharacterSelector', 'current_player', 'Count', 'RandomPicker', 'HeroSelector', 'draw', 'condition', 'DRAGON', 'range', 'hand', 'ManaChange', 'Choice', 'DEMON', 'add_buff', 'summon', 'auras', 'i', 'append', 'create_weapon', 'change_attack', 'Draw', 'CardSelector', 'CardQuery', 'WeaponCard', 'Weapon', None, 'cards', 'MURLOC', 'Kill', 'buffs', 'Transform', 'charge', 'AddCard', 'random_choice', 'die', 'value', 'index', 'spell_targetable', 'increase_health', 'Heal', 'divine_shield', 'GreaterThan', 'new_card', 'heal', 'effective_heal_power', 'c', 'health', 'TurnStarted', 'character', 'CARD_SOURCE', 'Attribute', 'PIRATE', 'WeaponSelector', 'p', 'IsMinion', 'overload', 'minion_card', 'choices', 'attacker', 'TOTEM', 'calculate_attack', 'extend', 'source', 'SpellCast', 'SecretCard', 'reveal', 'activate', 'bind', 'deactivate', 'unbind', 'change_temp_attack', 'spell_damage', 'BuffUntil', 'option', 'find_enemy_minion_spell_target', 'Frozen', 'x', 'trigger', 'm', 'TargetSelector', 'conditions', 't', 'stealth', 'CurrentPlayer', 'calculate_max_health', 'filter_func', 'find_friendly_minion_spell_target', 'Adjacent', 'MinionDied', 'MinionSummoned', 'Damaged', 'Whelp', 'demon_card', 'power', 'Charge', 'Taunt', 'bounce', 'deck', 'agent', 'Nerubian', 'opponent', 'ChoiceCard', 'windfury', 'Attack', 'And', 'OneIn', 'OpponentMinionCountIsGreaterThan', 'CardPlayed', 'amount', 'weapon', 'IsSpell', 'Treant', 'drawn', 'hunter', 'add_effect', 'choose_option', 'Bounce', 'is_minion', 'Equip', 'spare_part_list', 'LIST', 'source_list', 'ChangeTarget', 'NotCurrentTarget', 'Not', 'Imp', 'cards_played', 'type', 'Thaddius', 'AuraUntil', '_', 'enrage', 'characters', 'DREAM', 'powers', 'MinionPlaced', 'CharacterAttack', 'DidDamage', 'Windfury', 'reduce_cost', 'DivineShield', 'check_delayed', 'Feugen', 'InGraveyard', 'Stalagg', 'GiveAura', 'isinstance', 'left_minion', 'right_minion', 'combo', 'mirror', 'BluegillWarrior', 'increase_armor', 'remove', 'GrimscaleOracle', 'CharacterDamaged', 'frog', 'set_health_to', 'MurlocRaider', 'MurlocTidehunter', 'chosen_card', 'IsHero', 'IncreaseDurability', 'CantAttack', 'Wisps5', 'query', 'Stealth', 'find_enemy_minion_battlecry_target', 'mana', 'ManaCost', 'HasSecret', 'lightwarden', 'MinionHasDeathrattle', 'Remove', 'justice', 'hammer', 'ColdlightOracle', 'ColdlightSeer', 'MurlocTidecaller', 'MurlocWarleader', 'Puddlestomper', 'HasCardName', 'temp_attack', 'new_minon', 'hearthbreaker.cards.minions.druid', 'Immune', 'immune', 'draw_player', 'BloodFury', 'HasDivineShield', 'DruidOfTheClaw', 'CatForm', 'CatDruid', 'BearForm', 'BearDruid', 'Silence', 'random_draw', 'WorthlessImp', 'MindSpike', 'wrath', 'DeadMinionSelector', 'DruidOfTheFlame', 'FlameCatForm', 'FlameCat', 'FlameBirdForm', 'FlameBird', 'Destroy', 'beast_list', 'Huffer', 'Misha', 'Leokk', 'Boar', 'MechanicalDragonling', 'ExcessMana', 'Frog', 'find_enemy_spell_target', 'HealingTotem', 'NONE', 'beasts', 'find_friendly_minion_battlecry_target', 'LightsJustice', 'new_minion', 'remove_from_board', 'add_to_board', 'MirrorImage', 'MirrorImageMinion', 'Moonfi ...
# DSLPrimitiveType(int) dict_keys(['<unk>', '0'])
# DSLPrimitiveType(object) dict_keys(['<unk>', '2', '1', '3', '4', '5', '0', '6', '7', '8', '9', '10', '12', '11', '15', '80', '10000', '100', '20'])
# DSLPrimitiveType(singleton) dict_keys(['<unk>', True, False, None])
# DSLPrimitiveType(string) dict_keys(['<unk>', 'card_drawn', 'character_attack', 'Whelp', 'Nerubian', 'attack', 'minion_died', 'Treant', 'card_played', 'minion_played', "Gallywix's Coin", 'health', 'Druid of the Claw', 'Druid of the Flame', 'Healing Totem', 'Mirror Image', 'Silver Hand Recruit', 'Stoneclaw Totem', 'Druid of the Fang', 'Imp', 'Feugen', 'Stalagg', 'Demonfire', 'cards_played', 'pre_damage', 'Lord Jaraxxus', 'card_destroyed', 'Ysera', 'Acidic Swamp Ooze', 'Ancestral Healing', 'Animal Companion', 'Arcane Explosion', 'Arcane Intellect', 'Arcane Missiles', 'Arcane Shot', 'Arcanite Reaper', 'Assassinate', 'Backstab', 'Blessing of Kings', 'Blessing of Might', 'Bloodfen Raptor', 'Bloodlust', 'Bluegill Warrior', 'Boar', 'Charge', 'Chillwind Yeti', 'Claw', 'Cleave', 'Consecration', 'Core Hound', 'Corruption', 'Dalaran Mage', 'Divine Spirit', 'Dragonling Mechanic', 'Drain Life', 'Dread Infernal', 'Elven Archer', 'Excess Mana', 'Execute', 'Fan of Knives', 'Fireball', 'Flamestrike', 'Flametongue Totem', 'Frog', 'Frost Nova', 'Frost Shock', 'Frostbolt', 'Frostwolf Grunt', 'Goldshire Footman', 'Grimscale Oracle', 'Guardian of Kings', 'Gurubashi Berserker', 'Hammer of Wrath', 'Hand of Protection', 'Healing Touch', 'Hex', 'Holy Light', 'Holy Nova', 'Holy Smite', 'Houndmaster', 'Huffer', 'Humility', "Hunter's Mark", 'Ironforge Rifleman', 'Ironfur Grizzly', 'Kill Command', 'Kobold Geomancer', "Kor'kron Elite", 'Leokk', "Light's Justice", 'Lord of the Arena', 'Mechanical Dragonling', 'Mind Blast', 'Mind Control', 'Mind Vision', 'Misha', 'Moonfire', 'Murloc Raider', 'Murloc Scout', 'Murloc Tidehunter', 'Nightblade', 'Northshire Cleric', 'Novice Engineer', 'Oasis Snapjaw', 'Ogre Magi', 'Raid Leader', 'Razorfen Hunter', 'Reckless Rocketeer', 'River Crocolisk', 'Rockbiter Weapon', 'Sacrificial Pact', 'Sap', 'Savage Roar', 'Shadow Bolt', 'Shadow Word: Death', 'Shadow Word: Pain', 'Shattered Sun Cleric', 'Sheep', 'Shield Block', 'Shiv', 'Soulfire', 'Sprint', 'Starfire', 'Starving Buzzard', 'Stonetusk Boar', 'Stormpike Commando', 'Stormwind Champion', 'Swipe', 'Timber Wolf', 'Totemic Might', 'Tracking', 'Truesilver Champion', 'Tundra Rhino', 'Vanish', 'Voidwalker', 'Warsong Commander', 'Water Elemental', 'Whirlwind', 'Wicked Knife', 'Wild Growth', 'Windfury', 'Windspeaker', 'Wolfrider', "Alexstrasza's Champion", 'Ancestral Knowledge', "Anub'arak", 'Arcane Blast', 'Argent Horserider', 'Argent Lance', 'Argent Watchman', 'Armored Warhorse', 'Searing Totem', 'Tournament Medic', 'Wrath of Air Totem', "Ancestor's Call", 'Anima Golem', 'Antique Healbot', 'Arcane Nullifier X-21', 'Armor Plating', 'Blingtron 3000', 'Bolvar Fordragon', 'Bomb Lobber', 'Boom Bot', 'Bouncing Blade', 'Call Pet', 'Chicken', 'Clockwork Giant', 'Clockwork Gnome', 'Cobalt Guardian', 'Cobra Shot', 'Coghammer', 'Cogmaster', 'Crush', 'Dark Wispers', 'Give a minion +5/+5 and Taunt', 'Summon 5 Wisps', 'Darkbomb', 'Demonheart', 'Dr. Boom', 'Dunemaul Shaman', 'Enhance-o Mechano', 'Explosive Sheep', 'Feign Death', 'Fel Cannon', 'Fel Reaver', 'Finicky Cloakfield', 'Flame Leviathan', 'Flamecannon', 'Foe Reaper 4000', 'Force-Tank MAX', "Gahz'rilla", 'Gazlowe', 'Gilblin Stalker', 'Glaivezooka', 'Gnomeregan Infantry', 'Goblin Blastmage', 'Goblin Sapper', 'Grove Tender', 'Hemet Nesingwary', 'Hobgoblin', 'Illuminator', 'Imp-losion', 'Jeeves', 'Junkbot', 'Kezan Mystic', 'King of Beasts', 'Light of the Naaru', 'Lightbomb', "Lil' Exorcist", 'Lost Tallstrider', 'Malorne', 'Mech-Bear-Cat', 'Mechanical Yeti', 'Mechwarper', 'Mekgineer Thermaplugg', 'Metaltooth Leaper', 'Micro Machine', "Mimiron's Head", 'Mogor the Ogre', 'Muster for Battle', 'Neptulon', 'Ogre Brute', 'Ogre Ninja', 'Ogre Warmaul', 'One-eyed Cheat', 'Piloted Shredder', 'Puddlestomper', 'Quartermaster', 'Recombobulator', 'mana', 'Recycle', 'Reversing Switch', 'Rusty Horn', 'Sabotage', 'Salty Dog', 'Seal of Light', 'Shadowbomber', 'Shadowboxer', 'Shielded Minibot', 'Shieldmaiden', "Ship's Cannon", 'Shrinkmeister', 'Siege Engine', 'Sn ...

# %%
asdl_file = "/content/ShaderGenerator/torchASN/data/hearthstone/python_3_7_12_asdl.txt"
vocab = "/content/ShaderGenerator/torchASN/data/hearthstone/vocab.bin"
train_file = "/content/ShaderGenerator/torchASN/data/hearthstone/train.bin"
dev_file = "/content/ShaderGenerator/torchASN/data/hearthstone/dev.bin"
dropout = 0.3
enc_hid_size = 768
src_emb_size = 100
field_emb_size = 100
max_epoch = 100
clip_grad = 5.0
batch_size = 32
lr = 0.003
model_file = f"model.hearthstone.enc{enc_hid_size}.src{src_emb_size}.field{field_emb_size}.drop{dropout}.max_ep{max_epoch}.batch{batch_size}.lr{lr}.clip_grad{clip_grad}.bin"
save_to = f"/content/ShaderGenerator/torchASN/checkpoints/hearthstone/{model_file}"
log_every = 50
run_val_after = 5
max_decode_step = 70
max_naive_parse_depth = 18

@dataclass
class Arguments:
    asdl_file: str
    vocab: str
    train_file: str
    dev_file: str
    dropout: float
    enc_hid_size: int
    src_emb_size: int
    field_emb_size: int
    max_epoch: int
    clip_grad: float
    batch_size: int
    lr: float
    model_file: str
    save_to: str
    log_every: int
    run_val_after: int
    max_decode_step: int
    max_naive_parse_depth: int

args = Arguments(asdl_file=asdl_file, vocab=vocab, train_file=train_file, dev_file=dev_file, dropout=dropout, enc_hid_size=enc_hid_size, src_emb_size=src_emb_size, 
                 field_emb_size=field_emb_size, max_epoch=max_epoch, clip_grad=clip_grad, batch_size=batch_size, lr=lr, model_file=model_file, save_to=save_to, log_every=log_every, 
                 run_val_after=run_val_after, max_decode_step=max_decode_step, max_naive_parse_depth=max_naive_parse_depth)


train_set = Dataset.from_bin_file(args.train_file)
if args.dev_file:
    dev_set = Dataset.from_bin_file(args.dev_file)
else:
    dev_set = Dataset(examples=[])

vocab = pickle.load(open(args.vocab, 'rb'))
grammar = Grammar.from_text(open(args.asdl_file).read())
# transition_system = Registrable.by_name(args.transition_system)(grammar)
transition_system = Python3TransitionSystem(grammar)

parser = ASNParser(args, transition_system, vocab)
nn_utils.glorot_init(parser.parameters())

optimizer = optim.Adam(parser.parameters(), lr=args.lr)
best_acc = 0.0
log_every = args.log_every

train_begin = time.time()

for epoch in tqdm(range(1, args.max_epoch + 1)):
    train_iter = 0
    loss_val = 0.
    epoch_loss = 0.

    parser.train()

    epoch_begin = time.time()
    for batch_example in train_set.batch_iter(batch_size=args.batch_size, shuffle=False):
        optimizer.zero_grad()
        loss = parser.score(batch_example)
        loss_val += torch.sum(loss).data.item()
        epoch_loss += torch.sum(loss).data.item()
        loss = torch.mean(loss)

        loss.backward()
        torch.nn.utils.clip_grad_norm_(parser.parameters(), args.clip_grad)

        optimizer.step()
        train_iter += 1
        if train_iter % log_every == 0:
            print("[epoch {}, step {}] loss: {:.3f}".format(
                epoch, train_iter, loss_val / (log_every * args.batch_size)))
            loss_val = 0.

    # print(epoch, 'Train loss', '{:.3f}'.format(epoch_loss / len(train_set)), 'time elapsed %d' % (time.time() - epoch_begin))
    print('[epoch {}] train loss {:.3f}, epoch time {:.0f}, total time {:.0f}'.format(
        epoch, epoch_loss / len(train_set), time.time() - epoch_begin, time.time() - train_begin))
    if epoch % args.run_val_after == 0:
        eval_begin = time.time()
        parser.eval()
        with torch.no_grad():
            parse_results = [parser.naive_parse(ex) for ex in dev_set]
        match_results = [transition_system.compare_ast(r, e.tgt_ast) for r, e in zip(parse_results, dev_set)]
        match_acc = sum(match_results) * 1. / len(match_results)
        # print('Eval Acc', match_acc)
        print('[epoch {}] eval acc {:.3f}, eval time {:.0f}'.format(
            epoch, match_acc, time.time() - eval_begin))

        if match_acc >= best_acc:
            best_acc = match_acc
            parser.save(args.save_to)
